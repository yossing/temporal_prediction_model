# %% [markdown]
# # Preliminaries

# %%
import os
#can change Theano settings. It is much (!) faster on a GPU
os.environ["THEANO_FLAGS"] = "mode=FAST_RUN,device=gpu,floatX=float32,"

# %%
import importlib
from imp import reload
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
from network_code import data_handling as dat
from network_code import predictive_network_subclasses as pn
from visualisation import network_visualisation as vis
reload(dat)
reload(vis)
reload(pn)
# %matplotlib inline
# Out:
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GTX 1080 Ti (CNMeM is disabled, cuDNN 5005)

# %% [markdown]
# # Visual

# %% [markdown]
# ### Filepaths to preprocessed visual data and results

# %%
training_data_path = '../../data/preprocessed_visual_dataset.pkl'
main_save_path = '../../results/visual_results/'
if not os.path.isdir(main_save_path):
    os.makedirs(main_save_path)

# %% [markdown]
# ### Load data

# %%
reload(dat)
X_train, y_train, X_val, y_val = dat.load_1d_conv_vis_data(training_data_path, 
                                                          noise_ratio=0, 
                                                          input_noise_ratio=0,  
                                                          max_examples=20000, 
                                                          copy_data=True, 
                                                          norm_type=0, 
                                                          RF_size=20, 
                                                          t_filter_length=7)

# %% [markdown]
# ### Create new network

# %%
network_settings = {}
network_settings['nonlinearity'] = 'sigmoid'
network_settings['num_hidden_units']= 400
network_settings['num_layers']= 1
network_settings['regularization'] = 'l1'
network_settings['reg_factor'] =  10**-6
network_settings['save_path'] =  main_save_path + 'python_network.pkl'
network_settings['update_func'] = 'adam'
visNet= pn.PredictiveConv1DNetwork(X_train.shape, y_train.shape, **network_settings)

# %% [markdown]
# ### Train and validate network

# %%
for ii in range(0,2):
    #train network
    visNet.train_network(X_train,y_train,X_val = X_val, y_val = y_val, num_epochs=100, show_graph=True)
    #visualise spatial RFs at final time step
    input_weights = visNet.network_param_values[0]
    vis.plot_these_vis_weights(input_weights, keep_prop=0.1, tstep =-1,figsize = (12,12), order=1)
    plt.show()
# Out:
# Starting training ...
# Epoch 1 of 100 took 5.294s
#   training cost:		0.788934
#   validation cost:		1.172224
# Epoch 2 of 100 took 5.084s
#   training cost:		0.624090
#   validation cost:		0.570302
# Epoch 3 of 100 took 4.767s
#   training cost:		0.569979
#   validation cost:		0.506927
# Epoch 4 of 100 took 4.743s
#   training cost:		0.542713
#   validation cost:		0.480157
# Epoch 5 of 100 took 4.610s
#   training cost:		0.525467
#   validation cost:		0.465002
# Epoch 6 of 100 took 4.884s
#   training cost:		0.512508
#   validation cost:		0.454053
# Epoch 7 of 100 took 5.263s
#   training cost:		0.502663
#   validation cost:		0.446770
# Epoch 8 of 100 took 5.342s
#   training cost:		0.495032
#   validation cost:		0.440243
# Epoch 9 of 100 took 5.263s
#   training cost:		0.488744
#   validation cost:		0.436300
# Epoch 10 of 100 took 5.242s
#   training cost:		0.483798
#   validation cost:		0.432325
# Epoch 11 of 100 took 5.435s
#   training cost:		0.479554
#   validation cost:		0.429576
# Epoch 21 of 100 took 4.549s
#   training cost:		0.456940
#   validation cost:		0.412789
# Epoch 31 of 100 took 4.336s
#   training cost:		0.448219
#   validation cost:		0.409530
# Epoch 41 of 100 took 4.716s
#   training cost:		0.443394
#   validation cost:		0.405302
# Epoch 51 of 100 took 4.500s
#   training cost:		0.439875
#   validation cost:		0.402862
# Epoch 61 of 100 took 4.336s
#   training cost:		0.437961
#   validation cost:		0.402225
# Epoch 71 of 100 took 5.535s
#   training cost:		0.436693
#   validation cost:		0.400280
# Epoch 81 of 100 took 5.881s
#   training cost:		0.434498
#   validation cost:		0.399393
# Epoch 91 of 100 took 5.476s
#   training cost:		0.433670
#   validation cost:		0.399472
# Epoch 100 of 100 took 481.730s
#   training cost:		0.432395
#   validation cost:		0.397829
# Total time took 481.731s
# Starting training ...
# Epoch 1 of 100 took 4.669s
#   training cost:		0.432534
#   validation cost:		0.398254
# Epoch 2 of 100 took 4.345s
#   training cost:		0.432366
#   validation cost:		0.397601
# Epoch 3 of 100 took 4.423s
#   training cost:		0.432387
#   validation cost:		0.397874
# Epoch 4 of 100 took 4.567s
#   training cost:		0.432202
#   validation cost:		0.397547
# Epoch 5 of 100 took 4.434s
#   training cost:		0.431991
#   validation cost:		0.398263
# Epoch 6 of 100 took 4.561s
#   training cost:		0.431734
#   validation cost:		0.397985
# Epoch 7 of 100 took 4.324s
#   training cost:		0.432048
#   validation cost:		0.398003
# Epoch 8 of 100 took 4.319s
#   training cost:		0.431987
#   validation cost:		0.398128
# Epoch 9 of 100 took 5.254s
#   training cost:		0.431631
#   validation cost:		0.398169
# Epoch 10 of 100 took 5.556s
#   training cost:		0.431794
#   validation cost:		0.397503
# Epoch 11 of 100 took 5.033s
#   training cost:		0.431651
#   validation cost:		0.397966
# Epoch 21 of 100 took 4.993s
#   training cost:		0.430989
#   validation cost:		0.397516
# Epoch 31 of 100 took 5.056s
#   training cost:		0.430037
#   validation cost:		0.397550
# Epoch 41 of 100 took 5.357s
#   training cost:		0.429771
#   validation cost:		0.396870
# Epoch 51 of 100 took 5.024s
#   training cost:		0.428370
#   validation cost:		0.396138
# Epoch 61 of 100 took 4.683s
#   training cost:		0.428106
#   validation cost:		0.396212
# Epoch 71 of 100 took 5.525s
#   training cost:		0.428121
#   validation cost:		0.394595
# Epoch 81 of 100 took 5.252s
#   training cost:		0.427481
#   validation cost:		0.394987
# Epoch 91 of 100 took 4.563s
#   training cost:		0.427227
#   validation cost:		0.395029
# Epoch 100 of 100 took 496.202s
#   training cost:		0.426991
#   validation cost:		0.393861
# Total time took 496.202s

# %% [markdown]
# ### Save network

# %%
#save python network object
visNet.to_pickle()
#save parameters and settings to .mat file
params = visNet.get_network_results_and_settings()
mat_save_path = main_save_path + 'predictive_network.mat'
sio.savemat(mat_save_path, params)

# %% [markdown]
# # Auditory

# %% [markdown]
# ### Filepaths to preprocessed auditory data

# %%
training_data_dir = '../../data/preprocessed_auditory_dataset.mat'
main_save_path = '../../results/auditory_results/'

# %% [markdown]
# ### Load data

# %%
reload(dat)
X_train, y_train, X_val, y_val = load_auditory_data(training_data_dir, t_past=40, t_future=3, numfreq=32, 
                                                    noise_ratio=0, 
                                                    input_noise_ratio=0

# %% [markdown]
# ### Create new network

# %%
network_settings = {}

network_settings['model'] = 'fully_connected_nn'
network_settings['nonlinearity'] = 'sigmoid'
network_settings['num_hidden_units']= 400
network_settings['num_layers']= 1
network_settings['regularization'] = 'l1'
network_settings['reg_factor'] =  10**-3.5
network_settings['save_path'] =  main_save_path + 'python_network.pkl'
network_settings['update_func'] = 'adam'

audNet= pn.PredictiveFCN(X_train.shape, y_train.shape, **network_settings)

# %% [markdown]
# ### Train and validate network

# %%
import scipy.io
import os
for ii in range(0,2):
    audNet.train_network(X_train,y_train,X_val = X_val, y_val = y_val, num_epochs=100, show_graph=False)
    network_params = audNet.network_params
    vis.plot_these_aud_weights(network_params, keep_prop=0.01, figsize = (12,12))    
    plt.show()
# Out:
# Starting training ...
# Epoch 1 of 100 took 4.637s
#   training cost:		0.145306
#   validation cost:		0.173955
# Epoch 2 of 100 took 4.460s
#   training cost:		0.146101
#   validation cost:		0.173352
# Epoch 3 of 100 took 4.427s
#   training cost:		0.145852
#   validation cost:		0.175555
# Epoch 4 of 100 took 4.431s
#   training cost:		0.145732
#   validation cost:		0.174029
# Epoch 5 of 100 took 4.457s
#   training cost:		0.145772
#   validation cost:		0.175929
# Epoch 6 of 100 took 4.484s
#   training cost:		0.145004
#   validation cost:		0.173854
# Epoch 7 of 100 took 4.352s
#   training cost:		0.145453
#   validation cost:		0.174349
# Epoch 8 of 100 took 4.486s
#   training cost:		0.145458
#   validation cost:		0.175133
# Epoch 9 of 100 took 4.512s
#   training cost:		0.145456
#   validation cost:		0.173670
# Epoch 10 of 100 took 4.537s
#   training cost:		0.145522
#   validation cost:		0.176886
# Epoch 11 of 100 took 4.601s
#   training cost:		0.145620
#   validation cost:		0.174528
# Epoch 21 of 100 took 4.385s
#   training cost:		0.145221
#   validation cost:		0.174898
# Epoch 31 of 100 took 3.452s
#   training cost:		0.144851
#   validation cost:		0.174362
# Epoch 41 of 100 took 3.472s
#   training cost:		0.144811
#   validation cost:		0.174447
# Epoch 51 of 100 took 3.460s
#   training cost:		0.144837
#   validation cost:		0.173900
# Epoch 61 of 100 took 3.519s
#   training cost:		0.144462
#   validation cost:		0.173437
# Epoch 71 of 100 took 3.450s
#   training cost:		0.144141
#   validation cost:		0.174118
# Epoch 81 of 100 took 3.502s
#   training cost:		0.144499
#   validation cost:		0.174666
# Epoch 91 of 100 took 3.563s
#   training cost:		0.143630
#   validation cost:		0.173035
# Epoch 100 of 100 took 373.498s
#   training cost:		0.143661
#   validation cost:		0.173454
# Total time took 373.499s
# Starting training ...
# Epoch 1 of 100 took 3.462s
#   training cost:		0.143748
#   validation cost:		0.174618
# Epoch 2 of 100 took 3.454s
#   training cost:		0.144201
#   validation cost:		0.173021
# Epoch 3 of 100 took 3.456s
#   training cost:		0.143125
#   validation cost:		0.174267
# Epoch 4 of 100 took 3.453s
#   training cost:		0.143951
#   validation cost:		0.174595
# Epoch 5 of 100 took 3.506s
#   training cost:		0.143901
#   validation cost:		0.173235
# Epoch 6 of 100 took 3.449s
#   training cost:		0.143355
#   validation cost:		0.178035
# Epoch 7 of 100 took 3.486s
#   training cost:		0.143960
#   validation cost:		0.173507
# Epoch 8 of 100 took 3.529s
#   training cost:		0.143479
#   validation cost:		0.173856
# Epoch 9 of 100 took 3.491s
#   training cost:		0.143417
#   validation cost:		0.173149
# Epoch 10 of 100 took 3.506s
#   training cost:		0.143553
#   validation cost:		0.173267
# Epoch 11 of 100 took 3.499s
#   training cost:		0.144280
#   validation cost:		0.173553
# Epoch 21 of 100 took 3.649s
#   training cost:		0.143581
#   validation cost:		0.174435
# Epoch 31 of 100 took 3.487s
#   training cost:		0.143527
#   validation cost:		0.173795
# Epoch 41 of 100 took 3.439s
#   training cost:		0.143451
#   validation cost:		0.174139
# Epoch 51 of 100 took 3.440s
#   training cost:		0.143034
#   validation cost:		0.174115
# Epoch 61 of 100 took 3.439s
#   training cost:		0.143288
#   validation cost:		0.174133
# Epoch 71 of 100 took 3.462s
#   training cost:		0.142656
#   validation cost:		0.173335
# Epoch 81 of 100 took 3.440s
#   training cost:		0.143108
#   validation cost:		0.175577
# Epoch 91 of 100 took 3.392s
#   training cost:		0.142449
#   validation cost:		0.175245
# Epoch 100 of 100 took 346.392s
#   training cost:		0.142611
#   validation cost:		0.173331
# Total time took 346.392s

# %% [markdown]
# ### Save network

# %%
#save python network object
audNet.to_pickle()
#save parameters and settings to .mat file
params = audNet.get_network_results_and_settings()
mat_save_path = main_save_path + 'predictive_network.mat'
sio.savemat(mat_save_path, params)
