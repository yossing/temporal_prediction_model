# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os
os.environ["THEANO_FLAGS"] = "mode=FAST_RUN,device=gpu,floatX=float32,"

# %%
import sys
pred_path = '/home/yossi/yossi_local/predictive_coding_python'
if pred_path not in sys.path:
    sys.path.append(pred_path)
import importlib
from imp import reload
import data_handling as dat
import predictive_network_subclasses as pn
import numpy as np
import matplotlib.pyplot as plt
import os
import auditory_analysis as aan
import visualisation as vis
import pickle as pkl
from imp import reload
import results_dataframe_handling as rdh
import interactive_plotting as iplot
reload(iplot)
reload(aan)
reload(vis)
reload(pn)
reload(rdh)
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (20, 20)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0c86ea40-f246-4984-8566-1f1c493fdfd2">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # L2 regularisation on weights - original dataset

# %%
res_folder_path = '/home/yossi/Dropbox/visualRFNN/Datasets_new/visual/Dataset_python_olshausen_160x160x50_new/nnResults_after_refactor/l2_on_weights/'
res_pd = rdh.compile_results_pd(res_folder_path)
# res_pd.sort_values('final_val_cost')

# %%
l2_url_pd = iplot.get_urls_for_visual_df_data(res_pd, 'log_reg_factor', 'num_filters', 'final_val_cost', this_save_dir='yossi/l2_on_weights/', verbose=False)

# %%
iplot.plot_linked_heatmap_weights(l2_url_pd)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b017a47a-ad6b-4d86-9362-d44181393105"></div>
# </div>

# %% [markdown]
# # No noise, effect of L1 regularisation. Dataset with no writing

# %%
res_folder_path = '/home/yossi//Dropbox/visualRFNN/Datasets_new/visual/Dataset_python_olshausen_160x100x50_no_writing/nnResults/'
res_pd = rdh.compile_results_pd(res_folder_path)
# res_pd.sort_values('final_val_cost')

# %%
no_noise_url_pd = iplot.get_urls_for_visual_df_data(res_pd, 'log_reg_factor', 'num_filters', 'final_val_cost', this_save_dir='yossi/no_writing_no_noise/', verbose=False)

# %%
iplot.plot_linked_heatmap_weights(no_noise_url_pd)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="dd9332d3-e362-45c1-bc68-ee315cf864ce"></div>
# </div>

# %% [markdown]
# # Noise with SNR=4 added, effect of L1 regularisation. Dataset with no writing

# %%
res_folder_path = '/home/yossi//Dropbox/visualRFNN/Datasets_new/visual/Dataset_python_olshausen_160x100x50_no_writing/nnResults_with_noise/'
res_pd = rdh.compile_results_pd(res_folder_path)
# res_pd.sort_values('final_val_cost')

# %%
# root_save_dir ='/home/yossi/Dropbox/visualRFNN/interactive_figures/visual/no_writing/'
this_save_dir = 'yossi/no_writing_with_noise/'
with_noise_url_pd = iplot.get_urls_for_visual_df_data(res_pd, 'log_reg_factor', 'num_filters', 'final_val_cost', this_save_dir=this_save_dir, verbose=False)#, root_dir=root_save_dir, server_address='')

# %%
iplot.plot_linked_heatmap_weights(with_noise_url_pd)#, save_path=root_save_dir+this_save_dir+'interactive_plot.html')
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c9c739ee-28c7-44d9-8d99-e6e01f976d06"></div>
# </div>

# %% [markdown]
# # Effect of varying temporal window of prediction

# %%
res_folder_path = '/home/yossi//Dropbox/visualRFNN/Datasets_new/visual/Dataset_python_olshausen_160x100x50_no_writing/FCN_data/nnResults_with_noise_varying_t/'
res_pd = rdh.compile_results_pd(res_folder_path)
# res_pd.sort_values('final_val_cost')

# %%
predict_1_url_pd = iplot.get_urls_for_visual_df_data(res_pd, 'log_reg_factor', 't_future', 'final_val_cost', this_save_dir='yossi/visual_varying_t/', verbose=False)

# %%
iplot.plot_linked_heatmap_weights(predict_1_url_pd)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="de63b8c5-fadc-4e4b-bf00-c5b9ed477b2a"></div>
# </div>

# %%
aan.plot_3D_info_grid(res_pd.query('noise_ratio==0.5'), 'num_filters', 'log_reg_factor', 'final_val_cost')
# Out:
# array([[ 0.83441584,  0.83737924,  0.83742617,  0.84060722,  0.84852961,
#          0.85319402,  0.85769522,  0.86194012],
#        [ 0.84722377,  0.82018321,  0.81204159,  0.80406148,  0.79779419,
#          0.79838828,  0.81031318,  0.82946052]])
