# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os
os.environ["THEANO_FLAGS"] = "mode=FAST_RUN,device=gpu,floatX=float32,"

# %%
# %%capture --no-display
import sys
pred_path = '/home/yossi/yossi_local/predictive_coding_python'
if pred_path not in sys.path:
    sys.path.append(pred_path)
from imp import reload
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt
import data_handling as dat
import auditory_analysis as aan
import visualisation as vis
import interactive_plotting as iplot
reload(iplot)
reload(aan)
reload(vis)
# %matplotlib inline

# %pylab inline
# pylab.rcParams['figure.figsize'] = (20, 20)

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ccc1ddda-15b7-4fc4-b62d-67d02e0c015e">Loading BokehJS ...</span>
#     </div>

# %%
aud_res_df_path = '../Data/main_auditory_results_df.pkl'
aud_res_df = dat.load_pickled_data(aud_res_df_path)
aud_res_df = aud_res_df.loc[aud_res_df['nonlinearity']=='sigmoid'].query('noise_ratio==0.5')

# %%
# %%capture --no-display
this_save_dir = 'auditory_images/'
root_dir='/home/yossi/yossi_local/github/temporal_prediction_model/Figures/'
aud_url_pd = iplot.get_urls_for_auditory_df_data(aud_res_df.loc[aud_res_df['nonlinearity']=='sigmoid'], 'log_reg_factor', 'num_hidden_units', 'final_val_cost', server_address='', root_dir=root_dir, this_save_dir=this_save_dir, verbose=False)

# %%
# %%capture --no-display
iplot.plot_linked_heatmap_weights(aud_url_pd, x_key='log_reg_factor', y_key='num_hidden_units',RF_plot_title = 'Corresponding spectrotemporal RFs', add_t_slider=False)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a973b9cd-6a6f-459e-afac-6ed6bb2fa0e4"></div>
# </div>

# %% [markdown]
# ### Figure 8-Figure supplement 2  | Interactive figure exploring the relationship between the strength of  L1 regularisation on the network weights and the structure of the RFs  the network produces when the network is trained on auditory inputs.
#
# The left panel shows the performance of the newtwork with the hyperparameter settings specified on the x and y axes. The x axis signifies the strength of L1 reguilarisation placed on the weights of the network during training. The y axis signifies the number of hidden units in the network. The colour represents the performance of model measured by the reconstruction error on held out validation set at the end of training.
#
# Hover over a point in the left hand panel to show the corresponding spatial receptive fields of the network in the right hand panel. Using the settings near the right hand panel, zoom, pan and reset the image to explore the shapes of the spectrotemporal receptive fields.

# %%
res_df_path = '../Data/main_visual_results_df.pkl'
vis_res_df = dat.load_pickled_data(res_df_path)
vis_res_df = vis_res_df.query('noise_ratio==0.5')

# %%
# %%capture --no-display
this_save_dir = 'visual_images/'
root_dir='/home/yossi/yossi_local/github/temporal_prediction_model/Figures/'
visual_url_pd = iplot.get_urls_for_visual_df_data(vis_res_df, 'log_reg_factor', 'num_filters', 'final_val_cost', server_address='', root_dir=root_dir, this_save_dir=this_save_dir, verbose=False)

# %%
# %%capture --no-display
iplot.plot_linked_heatmap_weights(visual_url_pd, x_key='log_reg_factor', y_key='num_filters', RF_plot_title = 'Corresponding spatial RFs', add_t_slider=True)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="96c0cf19-0a14-49cd-af6b-0712c228a2ed"></div>
# </div>

# %% [markdown]
# ### Figure 8-Figure supplement 2  | Interactive figure exploring the relationship between the strength of  L1 regularisation on the network weights and the structure of the RFs  the network produces when the network is trained on visual inputs.
#
# The left panel shows the performance of the newtwork with the hyperparameter settings specified on the x and y axes. The x axis signifies the strength of L1 reguilarisation placed on the weights of the network during training. The y axis signifies the number of hidden units in the network. The colour represents the performance of model measured by the reconstruction error on held out validation set at the end of training.
#
# Hover over a point in the left panel to show the corresponding spatial receptive fields of the network in the right panel. Using the settings above the right hand panel, zoom, pan and reset the image to explore the shapes of the spatial receptive fields. Change the slider on the upper left to change the time-step of the spatial receptive fields being shown in the right hand panel.
